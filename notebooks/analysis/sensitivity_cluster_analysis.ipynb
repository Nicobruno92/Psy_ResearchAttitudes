# %% [markdown]
# # Cluster Analysis

# %%
import pandas as pd 
import math
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.mixture import GaussianMixture
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from matplotlib import cm
from scipy.stats import chi2_contingency
import statsmodels.api as sm
import numpy as np
import random
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
from kneed import KneeLocator
from scipy.stats import f_oneway, kruskal

# %% [markdown]
# Run this line to import utils:

# %%
# %run ../../utils/utils.py

# %% [markdown]
# ## 1. Load Data

# %%
df = pd.read_csv("../../data/preprocessed.csv")
df = data_featuring_cluster(df)
df.head()
# Out:
#    s1_edad  s1_genero  s1_experiencia_clinica                s1_educacion
# 0     41.0   Femenino                     1.2       Licenciatura de Grado  \
# 1     26.0   Femenino                     0.2       Licenciatura de Grado
# 2     27.0   Femenino                     1.0  Carrera de Especialización
# 3     30.0  Masculino                     1.3  Carrera de Especialización
# 4     26.0  Masculino                     2.0       Licenciatura de Grado
#
#   s1_titulo_terciario           s1_titulo s1_no_titulo_universitario
# 0                 NaN  Lic. en Psicología                        NaN  \
# 1                 NaN  Lic. en Psicología                        NaN
# 2                 NaN  Lic. en Psicología                        NaN
# 3                 NaN  Lic. en Psicología                        NaN
# 4                 NaN  Lic. en Psicología                        NaN
#
#    s1_horas_semana_pacientes_atendidos                    s1_contexto_trabajo
# 0                                 12.0                         Ámbito Privado  \
# 1                                 13.0  Ámbito Privado, Obra Social o Prepaga
# 2                                 30.0  Ámbito Privado, Obra Social o Prepaga
# 3                                 35.0                         Ámbito Privado
# 4                                 46.0       Ámbito Público (hospital u otro)
#
#                          s1_orientacion_teo  ...  s4_no_tiempo_aprender_tbe
# 0  Ecléctico (más de una de estas opciones)  ...                        4.0  \
# 1      Terapias Cognitivas/Comportamentales  ...                        1.0
# 2      Terapias Cognitivas/Comportamentales  ...                        1.0
# 3      Terapias Cognitivas/Comportamentales  ...                        2.0
# 4      Terapias Cognitivas/Comportamentales  ...                        4.0
#
#   s4_capacitacion_tbe_demasiado_dinero s4_no_saber_tbe
# 0                                  4.0             7.0  \
# 1                                  6.0             1.0
# 2                                  4.0             1.0
# 3                                  3.0             0.0
# 4                                  6.0             1.0
#
#   s4_entrenamiento_clinico_no_info_tbe s4_alianza_terapeutica_mas_importante
# 0                                  0.0                                   6.0  \
# 1                                  0.0                                   4.0
# 2                                  1.0                                   1.0
# 3                                  4.0                                   3.0
# 4                                  4.0                                   4.0
#
#    s4_terapias_igualmente_efectivas  s4_empleador_no_fondos_capacitacion_tbe
# 0                               4.0                                      6.0  \
# 1                               2.0                                      7.0
# 2                               1.0                                      0.0
# 3                               0.0                                      7.0
# 4                               1.0                                      7.0
#
#    s4_exp_clinica_mas_importante_que_evidencia_cientifica
# 0                                                2.0       \
# 1                                                3.0
# 2                                                4.0
# 3                                                3.0
# 4                                                4.0
#
#                      provincia_residencia  consentimiento_informado
# 0               Provincia de Buenos Aires                       NaN
# 1               Provincia de Buenos Aires                       NaN
# 2  Ciudad Autónoma de Buenos Aires (CABA)                       NaN
# 3               Provincia de Buenos Aires                       NaN
# 4               Provincia de Buenos Aires                       NaN
#
# [5 rows x 56 columns]

# %%
df_subset_s2 = create_section_2(df)
variables_s2 = ['s2_evidencia_cientifica', 's2_experiencia_personal', 's2_entrenamiento_clinica',
             's2_tratamiento_preferencia_consultantes', 's2_intuicion', 's2_terapia_personal']

df_subset_s3 = create_section_3(df) 
variables_s3 = ['s3_tratamiento_personal_consultantes', 's3_investigacion_empirica_ensayos_controlados',
             's3_supervision', 's3_estudios_de_caso', 's3_discusion_pares', 's3_libros', 
             's3_observaciones_casos_clinicos', 's3_medidas_resultado', 's3_guias_manuales_clinicos']

df_subset_s4 = create_section_4(df)

# List of variables for which you want to create point plots
variables_s4 = ['s4_apertura_terapias_desarrolladas_por_investigadores', 's4_nueva_terapia_intento',
             's4_terapia_manualizada', 's4_diagnosticos_utilizados_son_simples', 
             's4_tratamientos_preferencia_no_probados_ensayo_controlado', 's4_enfoque_tratamiento_individual', 
             's4_alianza_terapeutica_mas_importante', 's4_terapias_igualmente_efectivas', 
             's4_exp_clinica_mas_importante_que_evidencia_cientifica', 's4_actualizacion_info_cientifica', 
             's4_formacion_enfasis_investigacion', 's4_supervisores_terapia_evidencia_requerimiento', 
             's4_atraer_consultantes_con_tbe', 's4_hallazgos_cientificos_practica_diaria', 
             's4_interes_aprender_tbe', 's4_tratamientos_utilizados_base_empirica', 
             's4_complejidad_consultantes_ensayos_clinicos', 's4_consultantes_prefieren_otros_tratamientos', 
             's4_no_tiempo_aprender_tbe', 's4_capacitacion_tbe_demasiado_dinero', 
             's4_no_saber_tbe', 's4_entrenamiento_clinico_no_info_tbe', 
             's4_empleador_no_fondos_capacitacion_tbe']

# %% [markdown]
# ## 2. Cluster Analysis

# %% [markdown]
# ### 2.1 Combine Data From All Sections

# %%
# Combine data from all sections
all_sections = pd.concat([df_subset_s2[variables_s2], 
                          df_subset_s3[variables_s3], 
                          df_subset_s4[variables_s4]], axis=1)

# Add demographic variables for chi-square tests (optional)
demographic_vars = ['s1_orientacion_teo', 's1_edad', 's1_genero', 's1_horas_semana_pacientes_atendidos']
all_data = pd.concat([all_sections, df_subset_s2[demographic_vars]], axis=1)

# Clean data (drop rows with missing values)
all_data_clean = all_data.dropna()

# Separate features and target variable (optional for chi-square tests)
features = all_data_clean.drop(columns=demographic_vars)
target = all_data_clean['s1_orientacion_teo']

# %% [markdown]
# ### 2.2 Run a PCA And Determine Number Of Components And Clusters

# %% [markdown]
# To determine the optical number of clusters, we used the elbow curve, knee detector, and the silhoutte scores for verification

# %%
# Fix all sources of randomness
random.seed(42)
np.random.seed(42)

# Standardize the features before PCA
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features.astype(np.float32))  

# PCA with fixed random state
pca = PCA(random_state=42, svd_solver="full") 
pca_data = pca.fit_transform(features_scaled)
explained_variance_ratio = pca.explained_variance_ratio_
cumulative_variance = np.cumsum(explained_variance_ratio)

# Plot cumulative explained variance
plt.figure(figsize=(8, 5))
plt.plot(cumulative_variance, marker='o')
plt.axhline(y=0.8, color='r', linestyle='--', label='80% Explained Variance')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('PCA Explained Variance')
plt.legend()
plt.grid(True)
plt.show()

# Determine optimal number of components (e.g., 80% variance)
n_components = np.argmax(cumulative_variance >= 0.8) + 1
print(f"Number of components to retain: {n_components}")

# Re-run PCA with the chosen number of components
pca = PCA(n_components=n_components, random_state=42, svd_solver="full")
pca_reduced_data = pca.fit_transform(features_scaled)

# K-Means: Determine optimal clusters using Elbow Method
wcss = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, n_init=10, random_state=42, algorithm="lloyd")  # Ensure stability
    kmeans.fit(pca_reduced_data)
    wcss.append(kmeans.inertia_)

# Plot Elbow Curve
plt.figure(figsize=(8, 5))
plt.plot(range(1, 11), wcss, marker='o')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS (Within-Cluster Sum of Squares)')
plt.title('Elbow Method for Optimal K')
plt.grid(True)
plt.show()

# Identify optimal number of clusters using KneeLocator
optimal_k = KneeLocator(range(1, 11), wcss, curve="convex", direction="decreasing").knee
print(f"Optimal number of clusters: {optimal_k}")

# Compute silhouette scores for verification
silhouette_scores = []
for k in range(2, 11):  # Silhouette score is invalid for k=1
    kmeans = KMeans(n_clusters=k, n_init=10, random_state=42, algorithm="lloyd")
    labels = kmeans.fit_predict(pca_reduced_data)
    silhouette_avg = silhouette_score(pca_reduced_data, labels)
    silhouette_scores.append((k, silhouette_avg))
    print(f"For k={k}, the silhouette score is {silhouette_avg:.4f}")

# Fit K-Means with optimal clusters
kmeans = KMeans(n_clusters=optimal_k, n_init=10, random_state=42, algorithm="lloyd")
cluster_labels = kmeans.fit_predict(pca_reduced_data)

# Add cluster labels to the data
all_data_clean = all_data_clean.copy()  # Ensure we don't modify the original DataFrame
all_data_clean['Cluster'] = cluster_labels

# Visualize clusters in 2D PCA space
plt.figure(figsize=(8, 6))
for cluster in np.unique(cluster_labels):
    plt.scatter(pca_reduced_data[cluster_labels == cluster, 0], 
                pca_reduced_data[cluster_labels == cluster, 1], 
                label=f'Cluster {cluster}')
plt.title('Clusters in PCA Space')
plt.xlabel('PC 1')
plt.ylabel('PC 2')
plt.legend()
plt.show()
# Out:
# Number of components to retain: 20
# Optimal number of clusters: 4
# For k=2, the silhouette score is 0.2044
# For k=3, the silhouette score is 0.1104
# For k=4, the silhouette score is 0.0935
# For k=5, the silhouette score is 0.0950
# For k=6, the silhouette score is 0.0893
# For k=7, the silhouette score is 0.0753
# For k=8, the silhouette score is 0.0760
# For k=9, the silhouette score is 0.0673
# For k=10, the silhouette score is 0.0576

# %% [markdown]
# ### 2.3 Chi-Square Test

# %%
# Chi-Square Test
cross_tab = pd.crosstab(all_data_clean['Cluster'], all_data_clean['s1_orientacion_teo'])
chi2, p, dof, expected = chi2_contingency(cross_tab)
print("\n--- Chi-Square Test ---")
print(f"Chi²: {chi2:.2f}, p: {p:.4e}, DOF: {dof}")
print(cross_tab)

# PCA Loadings
loadings = pd.DataFrame(pca.components_.T, index=features.columns, 
                        columns=[f'PC{i+1}' for i in range(n_components)])
print("\n--- PCA Loadings ---")
print(loadings)
# Out:
# --- Chi-Square Test ---
# Chi²: 112.95, p: 3.6878e-20, DOF: 9
# s1_orientacion_teo  Ecléctico (más de una de estas opciones)  Psicoanálisis
# Cluster
# 0                                                          6              2  \
# 1                                                         14             31
# 2                                                          9              9
# 3                                                          3             38
#
# s1_orientacion_teo  Sistémica  Terapias Cognitivas/Comportamentales
# Cluster
# 0                           2                                    42
# 1                           7                                    24
# 2                           5                                    64
# 3                           0                                     5
#
# --- PCA Loadings ---
#                                                          PC1       PC2
# s2_evidencia_cientifica                            -0.257639 -0.075560  \
# s2_experiencia_personal                             0.057778 -0.319220
# s2_entrenamiento_clinica                            0.021272 -0.347001
# s2_tratamiento_preferencia_consultantes             0.014176 -0.287168
# s2_intuicion                                        0.026351 -0.143720
# s2_terapia_personal                                 0.137004 -0.237325
# s3_tratamiento_personal_consultantes                0.068305 -0.156539
# s3_investigacion_empirica_ensayos_controlados      -0.205352 -0.199228
# s3_supervision                                      0.037206 -0.235706
# s3_estudios_de_caso                                -0.046371 -0.304105
# s3_discusion_pares                                  0.045161 -0.252586
# s3_libros                                          -0.011784 -0.260693
# s3_observaciones_casos_clinicos                     0.115923 -0.321296
# s3_medidas_resultado                               -0.194996 -0.214437
# s3_guias_manuales_clinicos                         -0.255339 -0.093581
# s4_apertura_terapias_desarrolladas_por_investig... -0.174768 -0.043568
# s4_nueva_terapia_intento                           -0.084162 -0.113371
# s4_terapia_manualizada                              0.130021 -0.103014
# s4_diagnosticos_utilizados_son_simples              0.020890 -0.054216
# s4_tratamientos_preferencia_no_probados_ensayo_...  0.168263 -0.066992
# s4_enfoque_tratamiento_individual                   0.057992 -0.114249
# s4_alianza_terapeutica_mas_importante               0.097901 -0.056859
# s4_terapias_igualmente_efectivas                    0.171805  0.009021
# s4_exp_clinica_mas_importante_que_evidencia_cie...  0.232066 -0.028172
# s4_actualizacion_info_cientifica                   -0.236587 -0.032328
# s4_formacion_enfasis_investigacion                 -0.220126 -0.121833
# s4_supervisores_terapia_evidencia_requerimiento    -0.246553 -0.051735
# s4_atraer_consultantes_con_tbe                     -0.274202  0.003879
# s4_hallazgos_cientificos_practica_diaria           -0.295256 -0.032390
# s4_interes_aprender_tbe                            -0.297107  0.009963
# s4_tratamientos_utilizados_base_empirica           -0.285842  0.005375
# s4_complejidad_consultantes_ensayos_clinicos       -0.106241 -0.005358
# s4_consultantes_prefieren_otros_tratamientos        0.046998 -0.084302
# s4_no_tiempo_aprender_tbe                          -0.074634  0.091428
# s4_capacitacion_tbe_demasiado_dinero               -0.185705  0.105954
# s4_no_saber_tbe                                    -0.004942 -0.063695
# s4_entrenamiento_clinico_no_info_tbe               -0.045171  0.100380
# s4_empleador_no_fondos_capacitacion_tbe            -0.090451  0.002651
#
#                                                          PC3       PC4
# s2_evidencia_cientifica                            -0.051102  0.006457  \
# s2_experiencia_personal                             0.002948  0.255985
# s2_entrenamiento_clinica                           -0.036193  0.198028
# s2_tratamiento_preferencia_consultantes             0.117222  0.219802
# s2_intuicion                                        0.215973  0.104099
# s2_terapia_personal                                 0.016569 -0.018367
# s3_tratamiento_personal_consultantes                0.062482 -0.022966
# s3_investigacion_empirica_ensayos_controlados      -0.021050  0.068989
# s3_supervision                                     -0.217303 -0.118497
# s3_estudios_de_caso                                -0.032174 -0.032252
# s3_discusion_pares                                 -0.103247 -0.117507
# s3_libros                                          -0.119931 -0.205618
# s3_observaciones_casos_clinicos                    -0.025053 -0.038780
# s3_medidas_resultado                                0.022106  0.081903
# s3_guias_manuales_clinicos                          0.009996  0.034559
# s4_apertura_terapias_desarrolladas_por_investig...  0.112117  0.290749
# s4_nueva_terapia_intento                            0.120609  0.174204
# s4_terapia_manualizada                              0.198278 -0.258552
# s4_diagnosticos_utilizados_son_simples              0.215194 -0.294195
# s4_tratamientos_preferencia_no_probados_ensayo_...  0.156234 -0.235399
# s4_enfoque_tratamiento_individual                   0.146469 -0.241780
# s4_alianza_terapeutica_mas_importante               0.268616 -0.011968
# s4_terapias_igualmente_efectivas                    0.199618  0.120834
# s4_exp_clinica_mas_importante_que_evidencia_cie...  0.214098 -0.020039
# s4_actualizacion_info_cientifica                   -0.013765 -0.160407
# s4_formacion_enfasis_investigacion                  0.001185 -0.067118
# s4_supervisores_terapia_evidencia_requerimiento     0.005151 -0.067143
# s4_atraer_consultantes_con_tbe                      0.060397 -0.071998
# s4_hallazgos_cientificos_practica_diaria            0.049861 -0.169283
# s4_interes_aprender_tbe                             0.057387 -0.078361
# s4_tratamientos_utilizados_base_empirica           -0.001733 -0.154523
# s4_complejidad_consultantes_ensayos_clinicos        0.203110 -0.337746
# s4_consultantes_prefieren_otros_tratamientos        0.297810 -0.093916
# s4_no_tiempo_aprender_tbe                           0.344426  0.186913
# s4_capacitacion_tbe_demasiado_dinero                0.246082  0.149253
# s4_no_saber_tbe                                     0.337745 -0.074055
# s4_entrenamiento_clinico_no_info_tbe                0.256661 -0.022471
# s4_empleador_no_fondos_capacitacion_tbe             0.203427  0.260521
#
#                                                          PC5       PC6
# s2_evidencia_cientifica                            -0.134202  0.149191  \
# s2_experiencia_personal                             0.111979  0.130315
# s2_entrenamiento_clinica                            0.089055  0.159214
# s2_tratamiento_preferencia_consultantes             0.012535  0.237589
# s2_intuicion                                        0.102331  0.276179
# s2_terapia_personal                                 0.192767 -0.106485
# s3_tratamiento_personal_consultantes                0.289478  0.189034
# s3_investigacion_empirica_ensayos_controlados      -0.232923  0.078433
# s3_supervision                                      0.064242 -0.302187
# s3_estudios_de_caso                                -0.201597 -0.054150
# s3_discusion_pares                                  0.182923 -0.133347
# s3_libros                                          -0.046275 -0.209204
# s3_observaciones_casos_clinicos                     0.055957 -0.273712
# s3_medidas_resultado                               -0.114063 -0.058205
# s3_guias_manuales_clinicos                         -0.186957  0.001465
# s4_apertura_terapias_desarrolladas_por_investig... -0.234801 -0.052707
# s4_nueva_terapia_intento                           -0.271823 -0.258115
# s4_terapia_manualizada                             -0.150721  0.009464
# s4_diagnosticos_utilizados_son_simples             -0.338843  0.214856
# s4_tratamientos_preferencia_no_probados_ensayo_...  0.000188 -0.065321
# s4_enfoque_tratamiento_individual                  -0.210963 -0.252016
# s4_alianza_terapeutica_mas_importante               0.029519  0.080374
# s4_terapias_igualmente_efectivas                    0.058373 -0.028785
# s4_exp_clinica_mas_importante_que_evidencia_cie...  0.126374  0.133813
# s4_actualizacion_info_cientifica                    0.306826 -0.017957
# s4_formacion_enfasis_investigacion                  0.150487  0.138254
# s4_supervisores_terapia_evidencia_requerimiento     0.036124 -0.013760
# s4_atraer_consultantes_con_tbe                      0.124918  0.043391
# s4_hallazgos_cientificos_practica_diaria            0.176444  0.015367
# s4_interes_aprender_tbe                             0.101329 -0.019482
# s4_tratamientos_utilizados_base_empirica            0.208024  0.072004
# s4_complejidad_consultantes_ensayos_clinicos       -0.127065  0.149096
# s4_consultantes_prefieren_otros_tratamientos       -0.047455  0.167148
# s4_no_tiempo_aprender_tbe                           0.036024 -0.181176
# s4_capacitacion_tbe_demasiado_dinero                0.028542 -0.195496
# s4_no_saber_tbe                                     0.156234 -0.172536
# s4_entrenamiento_clinico_no_info_tbe                0.210556 -0.261038
# s4_empleador_no_fondos_capacitacion_tbe             0.072705 -0.245563
#
#                                                          PC7       PC8
# s2_evidencia_cientifica                            -0.212587 -0.028575  \
# s2_experiencia_personal                            -0.032383 -0.248348
# s2_entrenamiento_clinica                            0.098100 -0.307881
# s2_tratamiento_preferencia_consultantes             0.078923  0.015806
# s2_intuicion                                       -0.062460 -0.026989
# s2_terapia_personal                                -0.149194  0.067470
# s3_tratamiento_personal_consultantes               -0.106192 -0.159058
# s3_investigacion_empirica_ensayos_controlados      -0.136757  0.107071
# s3_supervision                                     -0.015883  0.044216
# s3_estudios_de_caso                                -0.067365  0.285915
# s3_discusion_pares                                  0.139684 -0.174826
# s3_libros                                          -0.204829 -0.071676
# s3_observaciones_casos_clinicos                     0.013948  0.114392
# s3_medidas_resultado                               -0.203030  0.238960
# s3_guias_manuales_clinicos                         -0.197758  0.113247
# s4_apertura_terapias_desarrolladas_por_investig...  0.215860 -0.137193
# s4_nueva_terapia_intento                            0.437212 -0.094248
# s4_terapia_manualizada                              0.130750 -0.222823
# s4_diagnosticos_utilizados_son_simples             -0.170871 -0.277233
# s4_tratamientos_preferencia_no_probados_ensayo_... -0.244239 -0.140986
# s4_enfoque_tratamiento_individual                   0.289941 -0.036917
# s4_alianza_terapeutica_mas_importante               0.004175  0.345902
# s4_terapias_igualmente_efectivas                    0.170868  0.255596
# s4_exp_clinica_mas_importante_que_evidencia_cie...  0.120484  0.115742
# s4_actualizacion_info_cientifica                    0.165491 -0.004575
# s4_formacion_enfasis_investigacion                  0.153737  0.106066
# s4_supervisores_terapia_evidencia_requerimiento    -0.068724  0.120178
# s4_atraer_consultantes_con_tbe                      0.103566 -0.053925
# s4_hallazgos_cientificos_practica_diaria            0.155336  0.025882
# s4_interes_aprender_tbe                             0.215076 -0.057753
# s4_tratamientos_utilizados_base_empirica            0.011864  0.049409
# s4_complejidad_consultantes_ensayos_clinicos        0.007238 -0.128304
# s4_consultantes_prefieren_otros_tratamientos        0.084302  0.311322
# s4_no_tiempo_aprender_tbe                          -0.126618 -0.058237
# s4_capacitacion_tbe_demasiado_dinero               -0.151024 -0.217372
# s4_no_saber_tbe                                    -0.045538  0.098022
# s4_entrenamiento_clinico_no_info_tbe               -0.204708 -0.089649
# s4_empleador_no_fondos_capacitacion_tbe            -0.191094 -0.086258
#
#                                                          PC9      PC10
# s2_evidencia_cientifica                            -0.012646 -0.155750  \
# s2_experiencia_personal                             0.338472 -0.097069
# s2_entrenamiento_clinica                            0.149030 -0.006211
# s2_tratamiento_preferencia_consultantes             0.119236  0.278508
# s2_intuicion                                       -0.351662  0.317343
# s2_terapia_personal                                -0.136260  0.134085
# s3_tratamiento_personal_consultantes               -0.331825 -0.307459
# s3_investigacion_empirica_ensayos_controlados      -0.157686 -0.016651
# s3_supervision                                      0.131251  0.220285
# s3_estudios_de_caso                                 0.038482  0.098879
# s3_discusion_pares                                 -0.368106 -0.084476
# s3_libros                                           0.055368 -0.230241
# s3_observaciones_casos_clinicos                     0.238384 -0.105628
# s3_medidas_resultado                               -0.121053 -0.027812
# s3_guias_manuales_clinicos                         -0.186192 -0.110560
# s4_apertura_terapias_desarrolladas_por_investig...  0.000474 -0.148947
# s4_nueva_terapia_intento                           -0.112276 -0.068606
# s4_terapia_manualizada                              0.015756  0.058749
# s4_diagnosticos_utilizados_son_simples              0.081316  0.047125
# s4_tratamientos_preferencia_no_probados_ensayo_...  0.035716 -0.306991
# s4_enfoque_tratamiento_individual                  -0.240495  0.035173
# s4_alianza_terapeutica_mas_importante              -0.019363 -0.246974
# s4_terapias_igualmente_efectivas                    0.169975 -0.284702
# s4_exp_clinica_mas_importante_que_evidencia_cie... -0.038808 -0.183137
# s4_actualizacion_info_cientifica                    0.082781  0.037882
# s4_formacion_enfasis_investigacion                 -0.164652 -0.049893
# s4_supervisores_terapia_evidencia_requerimiento     0.134255  0.012223
# s4_atraer_consultantes_con_tbe                     -0.004756  0.076954
# s4_hallazgos_cientificos_practica_diaria            0.073406 -0.074729
# s4_interes_aprender_tbe                            -0.012732 -0.069380
# s4_tratamientos_utilizados_base_empirica            0.212950 -0.131055
# s4_complejidad_consultantes_ensayos_clinicos        0.238280  0.119015
# s4_consultantes_prefieren_otros_tratamientos        0.063800  0.025698
# s4_no_tiempo_aprender_tbe                           0.079222 -0.153932
# s4_capacitacion_tbe_demasiado_dinero               -0.022764 -0.078057
# s4_no_saber_tbe                                     0.083484  0.336051
# s4_entrenamiento_clinico_no_info_tbe               -0.133969  0.132130
# s4_empleador_no_fondos_capacitacion_tbe             0.058322  0.128104
#
#                                                         PC11      PC12
# s2_evidencia_cientifica                            -0.102360 -0.044315  \
# s2_experiencia_personal                             0.064270 -0.006917
# s2_entrenamiento_clinica                            0.105385  0.076705
# s2_tratamiento_preferencia_consultantes            -0.195589  0.011883
# s2_intuicion                                        0.252110  0.119709
# s2_terapia_personal                                 0.249124 -0.240329
# s3_tratamiento_personal_consultantes               -0.231785 -0.092449
# s3_investigacion_empirica_ensayos_controlados      -0.069904  0.123605
# s3_supervision                                     -0.156643 -0.231558
# s3_estudios_de_caso                                -0.239716  0.151672
# s3_discusion_pares                                 -0.396622 -0.106761
# s3_libros                                           0.369628  0.034577
# s3_observaciones_casos_clinicos                    -0.038886  0.009907
# s3_medidas_resultado                               -0.038117  0.023946
# s3_guias_manuales_clinicos                          0.064351 -0.034628
# s4_apertura_terapias_desarrolladas_por_investig...  0.075406 -0.334424
# s4_nueva_terapia_intento                            0.253904 -0.137762
# s4_terapia_manualizada                             -0.135676  0.260679
# s4_diagnosticos_utilizados_son_simples              0.099904  0.069675
# s4_tratamientos_preferencia_no_probados_ensayo_...  0.196837 -0.030185
# s4_enfoque_tratamiento_individual                  -0.054454  0.245112
# s4_alianza_terapeutica_mas_importante               0.059415  0.037017
# s4_terapias_igualmente_efectivas                   -0.046302  0.220074
# s4_exp_clinica_mas_importante_que_evidencia_cie...  0.005722  0.018651
# s4_actualizacion_info_cientifica                    0.064674  0.059554
# s4_formacion_enfasis_investigacion                  0.095027  0.124790
# s4_supervisores_terapia_evidencia_requerimiento     0.030784  0.033115
# s4_atraer_consultantes_con_tbe                      0.111656 -0.000735
# s4_hallazgos_cientificos_practica_diaria           -0.026770  0.021267
# s4_interes_aprender_tbe                             0.091940  0.008681
# s4_tratamientos_utilizados_base_empirica            0.003285  0.113102
# s4_complejidad_consultantes_ensayos_clinicos       -0.252903 -0.297747
# s4_consultantes_prefieren_otros_tratamientos        0.007445 -0.512446
# s4_no_tiempo_aprender_tbe                          -0.282773  0.028839
# s4_capacitacion_tbe_demasiado_dinero               -0.145319 -0.001870
# s4_no_saber_tbe                                     0.122062  0.125887
# s4_entrenamiento_clinico_no_info_tbe                0.059333 -0.203418
# s4_empleador_no_fondos_capacitacion_tbe            -0.058967  0.217582
#
#                                                         PC13      PC14
# s2_evidencia_cientifica                            -0.013384  0.162904  \
# s2_experiencia_personal                             0.111049  0.071007
# s2_entrenamiento_clinica                            0.157281  0.242572
# s2_tratamiento_preferencia_consultantes            -0.178981 -0.067554
# s2_intuicion                                       -0.096648 -0.155961
# s2_terapia_personal                                -0.057072 -0.076010
# s3_tratamiento_personal_consultantes               -0.110330 -0.118266
# s3_investigacion_empirica_ensayos_controlados       0.204539 -0.269600
# s3_supervision                                     -0.299008 -0.063513
# s3_estudios_de_caso                                 0.392212 -0.175314
# s3_discusion_pares                                 -0.007307  0.120843
# s3_libros                                          -0.132055  0.034905
# s3_observaciones_casos_clinicos                    -0.040159 -0.086292
# s3_medidas_resultado                               -0.012596  0.223490
# s3_guias_manuales_clinicos                         -0.037099  0.290658
# s4_apertura_terapias_desarrolladas_por_investig... -0.181945 -0.051071
# s4_nueva_terapia_intento                            0.089526 -0.126386
# s4_terapia_manualizada                             -0.162370 -0.006924
# s4_diagnosticos_utilizados_son_simples             -0.166922  0.002277
# s4_tratamientos_preferencia_no_probados_ensayo_...  0.261867 -0.182159
# s4_enfoque_tratamiento_individual                  -0.014175  0.076495
# s4_alianza_terapeutica_mas_importante              -0.413696 -0.192912
# s4_terapias_igualmente_efectivas                    0.036679  0.196323
# s4_exp_clinica_mas_importante_que_evidencia_cie...  0.125255  0.012756
# s4_actualizacion_info_cientifica                    0.013572 -0.041887
# s4_formacion_enfasis_investigacion                  0.093355  0.189397
# s4_supervisores_terapia_evidencia_requerimiento    -0.323007  0.064421
# s4_atraer_consultantes_con_tbe                     -0.070148 -0.120310
# s4_hallazgos_cientificos_practica_diaria            0.082930 -0.178281
# s4_interes_aprender_tbe                             0.054287 -0.038201
# s4_tratamientos_utilizados_base_empirica           -0.000400 -0.142729
# s4_complejidad_consultantes_ensayos_clinicos        0.117916 -0.007710
# s4_consultantes_prefieren_otros_tratamientos        0.145080  0.009277
# s4_no_tiempo_aprender_tbe                          -0.096284  0.095326
# s4_capacitacion_tbe_demasiado_dinero               -0.060253  0.050378
# s4_no_saber_tbe                                     0.030544  0.400744
# s4_entrenamiento_clinico_no_info_tbe                0.264854  0.070097
# s4_empleador_no_fondos_capacitacion_tbe             0.031985 -0.418381
#
#                                                         PC15      PC16
# s2_evidencia_cientifica                             0.154979  0.120042  \
# s2_experiencia_personal                            -0.034857  0.028179
# s2_entrenamiento_clinica                           -0.018780 -0.058583
# s2_tratamiento_preferencia_consultantes             0.146800 -0.169135
# s2_intuicion                                        0.154620  0.300746
# s2_terapia_personal                                -0.125842  0.289388
# s3_tratamiento_personal_consultantes                0.227195 -0.355022
# s3_investigacion_empirica_ensayos_controlados       0.081898  0.011673
# s3_supervision                                      0.200177  0.112035
# s3_estudios_de_caso                                 0.206625  0.206067
# s3_discusion_pares                                 -0.247121  0.132678
# s3_libros                                           0.055259  0.120133
# s3_observaciones_casos_clinicos                    -0.116909 -0.178582
# s3_medidas_resultado                               -0.241714 -0.316749
# s3_guias_manuales_clinicos                         -0.074064  0.035558
# s4_apertura_terapias_desarrolladas_por_investig...  0.112219  0.029269
# s4_nueva_terapia_intento                           -0.003627  0.006251
# s4_terapia_manualizada                             -0.002833  0.052709
# s4_diagnosticos_utilizados_son_simples             -0.157041 -0.031288
# s4_tratamientos_preferencia_no_probados_ensayo_...  0.106860 -0.067171
# s4_enfoque_tratamiento_individual                   0.169310 -0.140701
# s4_alianza_terapeutica_mas_importante              -0.202447 -0.051908
# s4_terapias_igualmente_efectivas                    0.233692  0.038669
# s4_exp_clinica_mas_importante_que_evidencia_cie...  0.052873  0.238194
# s4_actualizacion_info_cientifica                   -0.119974  0.106566
# s4_formacion_enfasis_investigacion                 -0.264569  0.090794
# s4_supervisores_terapia_evidencia_requerimiento     0.307226  0.061341
# s4_atraer_consultantes_con_tbe                      0.164483 -0.227469
# s4_hallazgos_cientificos_practica_diaria           -0.000461  0.048068
# s4_interes_aprender_tbe                            -0.032706  0.012912
# s4_tratamientos_utilizados_base_empirica            0.070906  0.016872
# s4_complejidad_consultantes_ensayos_clinicos       -0.140621  0.077637
# s4_consultantes_prefieren_otros_tratamientos       -0.079182 -0.105641
# s4_no_tiempo_aprender_tbe                          -0.051258  0.423808
# s4_capacitacion_tbe_demasiado_dinero                0.067616  0.060280
# s4_no_saber_tbe                                     0.015379 -0.152788
# s4_entrenamiento_clinico_no_info_tbe                0.272032 -0.147340
# s4_empleador_no_fondos_capacitacion_tbe            -0.367647 -0.136415
#
#                                                         PC17      PC18
# s2_evidencia_cientifica                             0.008743  0.106205  \
# s2_experiencia_personal                            -0.000833 -0.024367
# s2_entrenamiento_clinica                            0.179848 -0.107531
# s2_tratamiento_preferencia_consultantes            -0.230661  0.257096
# s2_intuicion                                       -0.081182 -0.122031
# s2_terapia_personal                                 0.117693  0.360247
# s3_tratamiento_personal_consultantes                0.251673 -0.238254
# s3_investigacion_empirica_ensayos_controlados      -0.017585 -0.039390
# s3_supervision                                      0.203948 -0.207434
# s3_estudios_de_caso                                 0.001017 -0.110535
# s3_discusion_pares                                 -0.205004  0.075373
# s3_libros                                          -0.183144 -0.325966
# s3_observaciones_casos_clinicos                    -0.161095  0.144321
# s3_medidas_resultado                               -0.133847  0.204732
# s3_guias_manuales_clinicos                         -0.010679 -0.177953
# s4_apertura_terapias_desarrolladas_por_investig... -0.066928 -0.045310
# s4_nueva_terapia_intento                            0.016487 -0.041220
# s4_terapia_manualizada                             -0.352253 -0.001143
# s4_diagnosticos_utilizados_son_simples              0.042916  0.039160
# s4_tratamientos_preferencia_no_probados_ensayo_...  0.099593  0.372429
# s4_enfoque_tratamiento_individual                   0.356038  0.113053
# s4_alianza_terapeutica_mas_importante              -0.113039 -0.175591
# s4_terapias_igualmente_efectivas                   -0.103277 -0.105397
# s4_exp_clinica_mas_importante_que_evidencia_cie...  0.078221  0.005660
# s4_actualizacion_info_cientifica                   -0.050588 -0.079401
# s4_formacion_enfasis_investigacion                  0.139243 -0.004572
# s4_supervisores_terapia_evidencia_requerimiento     0.215548  0.195570
# s4_atraer_consultantes_con_tbe                     -0.071315  0.213633
# s4_hallazgos_cientificos_practica_diaria           -0.040716  0.045970
# s4_interes_aprender_tbe                            -0.073828  0.070129
# s4_tratamientos_utilizados_base_empirica           -0.011964 -0.026876
# s4_complejidad_consultantes_ensayos_clinicos        0.039699 -0.223483
# s4_consultantes_prefieren_otros_tratamientos        0.129214 -0.033414
# s4_no_tiempo_aprender_tbe                           0.060279  0.179303
# s4_capacitacion_tbe_demasiado_dinero                0.088984  0.017071
# s4_no_saber_tbe                                     0.150134 -0.117491
# s4_entrenamiento_clinico_no_info_tbe               -0.433044 -0.129544
# s4_empleador_no_fondos_capacitacion_tbe             0.227115 -0.187321
#
#                                                         PC19      PC20
# s2_evidencia_cientifica                             0.077949  0.044200
# s2_experiencia_personal                            -0.101817  0.213845
# s2_entrenamiento_clinica                           -0.204652 -0.010427
# s2_tratamiento_preferencia_consultantes             0.163096 -0.051020
# s2_intuicion                                        0.283975 -0.115500
# s2_terapia_personal                                -0.004109  0.317723
# s3_tratamiento_personal_consultantes                0.099606 -0.023607
# s3_investigacion_empirica_ensayos_controlados      -0.264426  0.042340
# s3_supervision                                     -0.090255  0.159372
# s3_estudios_de_caso                                -0.146908 -0.118014
# s3_discusion_pares                                 -0.045159 -0.121197
# s3_libros                                           0.187231 -0.079992
# s3_observaciones_casos_clinicos                     0.226221 -0.249218
# s3_medidas_resultado                                0.157076  0.184616
# s3_guias_manuales_clinicos                          0.015380  0.293440
# s4_apertura_terapias_desarrolladas_por_investig... -0.056872 -0.119879
# s4_nueva_terapia_intento                            0.112149 -0.103115
# s4_terapia_manualizada                             -0.281580  0.092345
# s4_diagnosticos_utilizados_son_simples              0.014406  0.010438
# s4_tratamientos_preferencia_no_probados_ensayo_... -0.065752 -0.186159
# s4_enfoque_tratamiento_individual                   0.110710  0.214125
# s4_alianza_terapeutica_mas_importante              -0.345534 -0.020944
# s4_terapias_igualmente_efectivas                    0.288786  0.191153
# s4_exp_clinica_mas_importante_que_evidencia_cie...  0.012271  0.236047
# s4_actualizacion_info_cientifica                   -0.128420  0.072774
# s4_formacion_enfasis_investigacion                  0.047901 -0.418128
# s4_supervisores_terapia_evidencia_requerimiento    -0.030569 -0.267571
# s4_atraer_consultantes_con_tbe                     -0.022540  0.182121
# s4_hallazgos_cientificos_practica_diaria            0.061269  0.114236
# s4_interes_aprender_tbe                            -0.051601  0.203102
# s4_tratamientos_utilizados_base_empirica            0.055505  0.014594
# s4_complejidad_consultantes_ensayos_clinicos        0.367155  0.028254
# s4_consultantes_prefieren_otros_tratamientos       -0.147622 -0.038285
# s4_no_tiempo_aprender_tbe                           0.082382 -0.083559
# s4_capacitacion_tbe_demasiado_dinero               -0.216912 -0.038957
# s4_no_saber_tbe                                    -0.167018 -0.159572
# s4_entrenamiento_clinico_no_info_tbe               -0.041280 -0.002884
# s4_empleador_no_fondos_capacitacion_tbe             0.164559  0.088171

# %% [markdown]
# ### 2.4 Estimate Size Effect

# %%
n = cross_tab.values.sum()  # Total number of observations
r, k = cross_tab.shape      # Rows and columns of the table
cramers_v = np.sqrt(chi2 / (n * (min(r-1, k-1))))
print(f"Cramér's V: {cramers_v:.2f}")
# Out:
# Cramér's V: 0.38

# %% [markdown]
# ### 2.5 Loadings for PCA

# %%
# Assuming 'pca' and 'features' are already defined
# Loadings for the first 5 principal components
loadings = pd.DataFrame(pca.components_[0:3, :], columns=features.columns)

# Translation dictionary
translation_dict = { 
    "s1_edad": "Age",
    "s1_genero": "Gender",
    "s1_experiencia_clinica": "Clinical Experience",
    "s1_educacion": "Education",
    "s1_titulo_terciario": "Tertiary Degree",
    "s1_titulo": "Degree",
    "s1_no_titulo_universitario": "No University Degree",
    "s1_horas_semana_pacientes_atendidos": "Hours per Week - Patients Attended",
    "s1_contexto_trabajo": "Work Context",
    "s1_orientacion_teo": "Theoretical Orientation",
    "s1_marco_teo_terapia_basada_arte": "Theoretical Framework - Art Therapy",
    "s1_marco_teo_psa": "Theoretical Framework - Psychoanalysis",
    "s1_marco_teo_tcc": "Theoretical Framework - CBT",
    "s1_marco_teo_humanista": "Theoretical Framework - Humanistic",
    "s1_marco_teo_eclectico": "Theoretical Framework - Eclectic",
    "s2_evidencia_cientifica": "Scientific Evidence",
    "s2_experiencia_personal": "Personal Experience",
    "s2_entrenamiento_clinica": "Clinical Training",
    "s2_tratamiento_preferencia_consultantes": "Patient Treatment Preferences",
    "s2_intuicion": "Intuition",
    "s2_terapia_personal": "Personal Therapy",
    "s3_tratamiento_personal_consultantes": "Personal Treatment Experience",
    "s3_investigacion_empirica_ensayos_controlados": "Empirical Research - RCTs",
    "s3_supervision": "Supervision",
    "s3_estudios_de_caso": "Case Studies",
    "s3_discusion_pares": "Peer Discussions",
    "s3_libros": "Books",
    "s3_observaciones_casos_clinicos": "Clinical Case Observations",
    "s3_medidas_resultado": "Outcome Measures",
    "s3_guias_manuales_clinicos": "Clinical Manuals",
    "s4_apertura_terapias_desarrolladas_por_investigadores": "Openness to Research-based Therapies",
    "s4_actualizacion_info_cientifica": "Scientific Information Updates",
    "s4_formacion_enfasis_investigacion": "Research-Emphasized Training",
    "s4_supervisores_terapia_evidencia_requerimiento": "Supervisors Require Evidence-based Therapy",
    "s4_tratamientos_cientificos_eficientes": "Efficient Scientific Treatments",
    "s4_atraer_consultantes_con_tbe": "Attract Patients with EBTs",
    "s4_hallazgos_cientificos_practica_diaria": "Scientific Findings in Daily Practice",
    "s4_nueva_terapia_intento": "Trying New Therapies",
    "s4_interes_aprender_tbe": "Interest in Learning EBTs",
    "s4_tratamientos_utilizados_base_empirica": "Empirical Basis for Used Treatments",
    "s4_complejidad_consultantes_ensayos_clinicos": "Complexity of Patients in RCTs",
    "s4_consultantes_prefieren_otros_tratamientos": "Patients Prefer Other Treatments",
    "s4_terapia_manualizada": "Manualized Therapy",
    "s4_diagnosticos_utilizados_son_simples": "Diagnosis Simplicity",
    "s4_tratamientos_preferencia_no_probados_ensayo_controlado": "Preference for Non-RCT Treatments",
    "s4_enfoque_tratamiento_individual": "Individualized Treatment Approach",
    "s4_no_tiempo_aprender_tbe": "No Time to Learn EBTs",
    "s4_capacitacion_tbe_demasiado_dinero": "EBT Training is Too Expensive",
    "s4_no_saber_tbe": "Lack of Knowledge on EBTs",
    "s4_entrenamiento_clinico_no_info_tbe": "Clinical Training Lacks EBT Info",
    "s4_alianza_terapeutica_mas_importante": "Therapeutic Alliance is More Important",
    "s4_terapias_igualmente_efectivas": "All Therapies are Equally Effective",
    "s4_empleador_no_fondos_capacitacion_tbe": "Employer Lacks Funds for EBT Training",
    "s4_exp_clinica_mas_importante_que_evidencia_cientifica": "Clinical Experience > Scientific Evidence",
    "provincia_residencia": "Residence Province",
    "consentimiento_informado": "Informed Consent"
}

# Rename columns
loadings.rename(columns=translation_dict, inplace=True)

# Maximum value for scaling purposes
maxPC = 1.01 * np.max(np.abs(loadings.values))

# Create subplots for each of the first 5 components
fig, axes = plt.subplots(3, 1, figsize=(10, 12), sharex=True)

for i, ax in enumerate(axes):
    pc_loadings = loadings.iloc[i, :]
    ax.bar(pc_loadings.index, pc_loadings.values, color='skyblue')
    ax.set_ylim(-maxPC, maxPC)
    ax.set_title(f"Loadings for PC{i+1}", fontsize=12)
    ax.axhline(0, color='black', linewidth=0.8, linestyle='--')
    ax.tick_params(axis='x', rotation=90, labelsize=8)

fig.tight_layout(rect=[0, 0, 1, 0.96])

# Show plot
plt.show()

# %% [markdown]
# ## 3. Calculate Standard Deviation And Select Top Variables For Radar Plot

# %% [markdown]
# To visualize the difference of the variables across the clusters, we 1) added the cluster labels to the original variables, 2) calculate the standard deviation across clusters for each variable, 3) selected the top 5 variables with the highest variation, and 4) display a radar plot

# %%
# Add cluster labels to the original features
cluster_data = features.copy()
cluster_data['Cluster'] = cluster_labels

# Compute mean values of variables for each cluster
cluster_means = cluster_data.groupby('Cluster').mean()

# Display cluster profiles
print("\nCluster Profiles (Variable Means):")
cluster_means

# Optional: Visualize profiles using radar plots or heatmaps
# Out:
# Cluster Profiles (Variable Means):
#          s2_evidencia_cientifica  s2_experiencia_personal
# Cluster
# 0                       6.269231                 3.384615  \
# 1                       5.236842                 6.026316
# 2                       6.482759                 5.689655
# 3                       3.260870                 5.760870
#
#          s2_entrenamiento_clinica  s2_tratamiento_preferencia_consultantes
# Cluster
# 0                        3.480769                                 1.519231  \
# 1                        5.763158                                 4.144737
# 2                        5.954023                                 3.597701
# 3                        5.413043                                 3.108696
#
#          s2_intuicion  s2_terapia_personal
# Cluster
# 0            1.807692             2.423077  \
# 1            3.644737             5.263158
# 2            2.574713             4.367816
# 3            2.673913             6.130435
#
#          s3_tratamiento_personal_consultantes
# Cluster
# 0                                    5.019231  \
# 1                                    5.657895
# 2                                    5.505747
# 3                                    6.065217
#
#          s3_investigacion_empirica_ensayos_controlados  s3_supervision
# Cluster
# 0                                             3.038462        4.461538  \
# 1                                             3.526316        5.263158
# 2                                             5.057471        6.114943
# 3                                             1.717391        6.086957
#
#          s3_estudios_de_caso  ...  s4_hallazgos_cientificos_practica_diaria
# Cluster                       ...
# 0                   2.769231  ...                                  6.000000  \
# 1                   4.421053  ...                                  5.381579
# 2                   4.678161  ...                                  6.735632
# 3                   3.608696  ...                                  1.760870
#
#          s4_interes_aprender_tbe  s4_tratamientos_utilizados_base_empirica
# Cluster
# 0                       6.192308                                  6.153846  \
# 1                       5.144737                                  4.828947
# 2                       6.701149                                  6.735632
# 3                       1.456522                                  1.565217
#
#          s4_complejidad_consultantes_ensayos_clinicos
# Cluster
# 0                                            5.288462  \
# 1                                            4.907895
# 2                                            4.609195
# 3                                            3.608696
#
#          s4_consultantes_prefieren_otros_tratamientos
# Cluster
# 0                                            2.346154  \
# 1                                            4.223684
# 2                                            2.402299
# 3                                            3.086957
#
#          s4_no_tiempo_aprender_tbe  s4_capacitacion_tbe_demasiado_dinero
# Cluster
# 0                         2.423077                              4.730769  \
# 1                         2.763158                              4.105263
# 2                         1.390805                              3.839080
# 3                         0.500000                              1.130435
#
#          s4_no_saber_tbe  s4_entrenamiento_clinico_no_info_tbe
# Cluster
# 0               1.423077                              3.865385  \
# 1               2.828947                              4.026316
# 2               1.172414                              2.620690
# 3               0.978261                              2.173913
#
#          s4_empleador_no_fondos_capacitacion_tbe
# Cluster
# 0                                       2.326923
# 1                                       3.157895
# 2                                       2.298851
# 3                                       0.586957
#
# [4 rows x 38 columns]

# %%
# Calculate standard deviation across clusters for each variable
std_across_clusters = cluster_means.std(axis=0)

# Sort by importance (higher std means greater difference across clusters)
sorted_variables = std_across_clusters.sort_values(ascending=False)
print("Variables with highest variation across clusters:")
print(sorted_variables.head(10))
# Out:
# Variables with highest variation across clusters:
# s4_interes_aprender_tbe                            2.368464
# s4_tratamientos_utilizados_base_empirica           2.312465
# s4_atraer_consultantes_con_tbe                     2.233654
# s4_hallazgos_cientificos_practica_diaria           2.209545
# s4_actualizacion_info_cientifica                   2.204284
# s4_supervisores_terapia_evidencia_requerimiento    2.134748
# s4_formacion_enfasis_investigacion                 1.765679
# s4_capacitacion_tbe_demasiado_dinero               1.591802
# s2_terapia_personal                                1.587797
# s2_evidencia_cientifica                            1.471932
# dtype: float64

# %% [markdown]
# ### 3.1 Radar Plot

# %%
# Define top variables for radar plot with translations
top_variables = {
    "s4_interes_aprender_tbe":                         "Interest in Learning EBTs",
    "s4_tratamientos_utilizados_base_empirica":        "Treatments with Empirical Basis",
    "s4_atraer_consultantes_con_tbe":                  "EBTs Attract Clients",
    "s4_hallazgos_cientificos_practica_diaria":        "Scientific Findings in Daily Practice",
    "s4_actualizacion_info_cientifica":                "Keeping Up with Scientific Research",
    "s2_terapia_personal":                             "Personal Therapy",
    "s2_evidencia_cientifica":                         "Scientific Evidence"
}

# Reduce the cluster means to the selected top variables
valid_columns = [col for col in top_variables.keys() if col in cluster_means.columns]
actual_means = cluster_means[valid_columns]

# Radar plot setup
angles = np.linspace(0, 2 * np.pi, len(valid_columns), endpoint=False).tolist()
angles += angles[:1]  # Close the circle

fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))

# Cluster labels — updated to reflect new composition
cluster_labels_radar_plot = {
    0: "Cluster 0 (CBT Dominant)",
    1: "Cluster 1 (Mixed Orientations)",
    2: "Cluster 2 (CBT Less Dominant)",
    3: "Cluster 3 (Psychoanalysis Dominant)"
}

# Define a more distinct color palette manually
custom_colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728"]  # Blue, Orange, Green, Red

line_styles = ['solid', 'dashed', 'dotted', 'dashdot']
markers = ['o', 's', '^', 'D']

# Iterate over each cluster and plot with professional styling
for idx, (cluster, color) in enumerate(zip(actual_means.index, custom_colors)):
    values = actual_means.loc[cluster].tolist()
    values += values[:1]  # Close the circle
    ax.plot(angles, values, label=cluster_labels_radar_plot[cluster], linewidth=2.5, linestyle=line_styles[idx], marker=markers[idx], color=color)
    ax.fill(angles, values, alpha=0.15, color=color)

# Improve Axis Labels
ax.set_xticks(angles[:-1])  
ax.set_xticklabels(top_variables.values(), fontsize=12, fontweight='bold')

# Rotate labels for clarity
for label, angle in zip(ax.get_xticklabels(), angles[:-1]):
    angle_deg = np.degrees(angle)
    if 90 < angle_deg < 270:
        label.set_rotation(angle_deg + 180)
        label.set_ha("right")
    else:
        label.set_rotation(angle_deg)
        label.set_ha("left")

# Improve Grid and Borders
ax.yaxis.grid(True, linestyle="dashed", alpha=0.4, linewidth=1)
ax.xaxis.grid(False)  # Remove radial grid for clarity
ax.spines["polar"].set_visible(True)
ax.spines["polar"].set_linestyle("dotted")

# Improve Radial Scale
ax.set_yticks([1, 3, 5, 7])
ax.set_yticklabels(["1", "3", "5", "7"], fontsize=10, fontweight="bold")

# Remove title, replace with caption
fig.suptitle("", fontsize=0)  

# Add legend box
legend = ax.legend(loc="upper left", bbox_to_anchor=(-0.50, 1.06), frameon=True, fontsize=12)
legend.get_frame().set_edgecolor("black")
legend.get_frame().set_linewidth(1.5)
legend.get_frame().set_facecolor("white")
legend.get_frame().set_alpha(0.9)

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import f_oneway

translation_dict = {
    "s2_evidencia_cientifica": "Scientific Evidence",
    "s2_experiencia_personal": "Personal Experience",
    "s2_entrenamiento_clinica": "Clinical Training",
    "s2_tratamiento_preferencia_consultantes": "Client Treatment Preferences",
    "s2_intuicion": "Intuition",
    "s2_terapia_personal": "Personal Therapy",
    "s3_tratamiento_personal_consultantes": "Personal Treatment Experience",
    "s3_investigacion_empirica_ensayos_controlados": "Empirical Research (RCTs)",
    "s3_supervision": "Supervision",
    "s3_estudios_de_caso": "Case Studies",
    "s3_discusion_pares": "Peer Discussions",
    "s3_libros": "Books",
    "s3_observaciones_casos_clinicos": "Clinical Case Observations",
    "s3_medidas_resultado": "Outcome Measures",
    "s3_guias_manuales_clinicos": "Clinical Manuals & Guidelines",
    "s4_apertura_terapias_desarrolladas_por_investigadores": "Openness to Researcher-Developed Therapies",
    "s4_nueva_terapia_intento": "Willingness to Try New Therapy",
    "s4_terapia_manualizada": "Therapy Cannot Be Manualized",
    "s4_diagnosticos_utilizados_son_simples": "Diagnoses in RCTs Too Simple",
    "s4_tratamientos_preferencia_no_probados_ensayo_controlado": "Preferred Treatments Not RCT-Tested",
    "s4_enfoque_tratamiento_individual": "Focus on Individual Treatment",
    "s4_alianza_terapeutica_mas_importante": "Therapeutic Alliance > Specific Therapy",
    "s4_terapias_igualmente_efectivas": "Most Therapies Equally Effective",
    "s4_exp_clinica_mas_importante_que_evidencia_cientifica": "Clinical Experience > Scientific Evidence",
    "s4_actualizacion_info_cientifica": "Keeping Up with Scientific Research",
    "s4_formacion_enfasis_investigacion": "Research-Emphasized Training",
    "s4_supervisores_terapia_evidencia_requerimiento": "Supervisors Require EBTs",
    "s4_atraer_consultantes_con_tbe": "EBTs Attract Clients",
    "s4_hallazgos_cientificos_practica_diaria": "Scientific Findings in Daily Practice",
    "s4_interes_aprender_tbe": "Interest in Learning EBTs",
    "s4_tratamientos_utilizados_base_empirica": "Treatments with Empirical Basis",
    "s4_complejidad_consultantes_ensayos_clinicos": "Complexity of Clients vs. RCT Samples",
    "s4_consultantes_prefieren_otros_tratamientos": "Clients Prefer Non-EBT Treatments",
    "s4_no_tiempo_aprender_tbe": "No Time to Learn EBTs",
    "s4_capacitacion_tbe_demasiado_dinero": "EBT Training Too Expensive",
    "s4_no_saber_tbe": "Do Not Know Which Treatments Are EBTs",
    "s4_entrenamiento_clinico_no_info_tbe": "Clinical Training Insufficient on EBTs",
    "s4_empleador_no_fondos_capacitacion_tbe": "Employer Lacks Funds for EBT Training",
}

cluster_labels_radar_plot = {
    0: "Cluster 0 (CBT Dominant)",
    1: "Cluster 1 (CBT Mixed)",
    2: "Cluster 2 (Mixed Orientations)",
    3: "Cluster 3 (Psychoanalysis Dominant)"
}
custom_colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728"]
line_styles = ['solid', 'dashed', 'dotted', 'dashdot']
markers = ['o', 's', '^', 'D']


def plot_radar(top_variables):
    valid_columns = [col for col in top_variables.keys() if col in cluster_means.columns]
    actual_means = cluster_means[valid_columns]
    angles = np.linspace(0, 2 * np.pi, len(valid_columns), endpoint=False).tolist()
    angles += angles[:1]
    fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))
    for idx, (cluster, color) in enumerate(zip(actual_means.index, custom_colors)):
        values = actual_means.loc[cluster].tolist()
        values += values[:1]
        ax.plot(angles, values, label=cluster_labels_radar_plot[cluster],
                linewidth=2.5, linestyle=line_styles[idx], marker=markers[idx], color=color)
        ax.fill(angles, values, alpha=0.15, color=color)
    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(top_variables.values(), fontsize=12, fontweight='bold')
    for label, angle in zip(ax.get_xticklabels(), angles[:-1]):
        angle_deg = np.degrees(angle)
        if 90 < angle_deg < 270:
            label.set_rotation(angle_deg + 180)
            label.set_ha("right")
        else:
            label.set_rotation(angle_deg)
            label.set_ha("left")
    ax.yaxis.grid(True, linestyle="dashed", alpha=0.4, linewidth=1)
    ax.xaxis.grid(False)
    ax.spines["polar"].set_visible(True)
    ax.spines["polar"].set_linestyle("dotted")
    ax.set_yticks([1, 3, 5, 7])
    ax.set_yticklabels(["1", "3", "5", "7"], fontsize=10, fontweight="bold")
    fig.suptitle("", fontsize=0)
    legend = ax.legend(loc="upper left", bbox_to_anchor=(-0.50, 1.06), frameon=True, fontsize=12)
    legend.get_frame().set_edgecolor("black")
    legend.get_frame().set_linewidth(1.5)
    legend.get_frame().set_facecolor("white")
    legend.get_frame().set_alpha(0.9)
    plt.show()


# ── Precompute std once — used by approaches 1, 4 ────────────────────────────
std_across_clusters = cluster_means.std(axis=0).sort_values(ascending=False)


# APPROACH 1 — Highest variance (std of cluster means)
top_vars_1 = {v: translation_dict.get(v, v) for v in std_across_clusters.head(5).index}
print("APPROACH 1 — Highest variance (std of cluster means):")
for v, s in std_across_clusters.head(5).items():
    print(f"  {translation_dict.get(v,v):<55} std = {s:.3f}")
plot_radar(top_vars_1)


# APPROACH 2 — One variable per principal component (highest absolute loading)
loadings_df = pd.DataFrame(
    pca.components_.T, index=features.columns,
    columns=[f'PC{i+1}' for i in range(pca.n_components_)]
)
top5_pca, used = [], set()
for pc in [f'PC{i+1}' for i in range(5)]:
    for var in loadings_df[pc].abs().sort_values(ascending=False).index:
        if var not in used:
            top5_pca.append(var)
            used.add(var)
            break
top_vars_2 = {v: translation_dict.get(v, v) for v in top5_pca}
print("\nAPPROACH 2 — Highest loading per PC (PC1-PC5):")
for i, v in enumerate(top5_pca):
    pc = f'PC{i+1}'
    print(f"  {pc}: {translation_dict.get(v,v):<55} loading = {loadings_df.loc[v, pc]:.3f}")
plot_radar(top_vars_2)


# APPROACH 3 — ANOVA F-statistic across clusters
_cda = features.copy()
_cda['Cluster'] = cluster_labels
f_stats = {}
for var in features.columns:
    groups = [_cda[_cda['Cluster'] == c][var].dropna().values
              for c in sorted(_cda['Cluster'].unique())]
    if all(len(g) > 1 for g in groups):
        f_stats[var] = f_oneway(*groups)[0]
f_series = pd.Series(f_stats).sort_values(ascending=False)
top_vars_3 = {v: translation_dict.get(v, v) for v in f_series.head(5).index}
print("\nAPPROACH 3 — Top 5 by ANOVA F-statistic across clusters:")
for v, f in f_series.head(5).items():
    print(f"  {translation_dict.get(v,v):<55} F = {f:.2f}")
plot_radar(top_vars_3)


# APPROACH 4 — Stratified by conceptual domain
domains = {
    "EBT attitudes":            ["s4_interes_aprender_tbe", "s4_tratamientos_utilizados_base_empirica",
                                  "s4_hallazgos_cientificos_practica_diaria", "s4_atraer_consultantes_con_tbe",
                                  "s4_apertura_terapias_desarrolladas_por_investigadores"],
    "Anti-EBT attitudes":       ["s4_exp_clinica_mas_importante_que_evidencia_cientifica",
                                  "s4_terapias_igualmente_efectivas", "s4_alianza_terapeutica_mas_importante",
                                  "s4_terapia_manualizada", "s4_tratamientos_preferencia_no_probados_ensayo_controlado"],
    "Practice sources":         ["s3_supervision", "s3_observaciones_casos_clinicos",
                                  "s3_investigacion_empirica_ensayos_controlados",
                                  "s3_guias_manuales_clinicos", "s3_tratamiento_personal_consultantes"],
    "Influences on orientation":["s2_terapia_personal", "s2_evidencia_cientifica",
                                  "s2_experiencia_personal", "s2_entrenamiento_clinica"],
    "EBT barriers":             ["s4_capacitacion_tbe_demasiado_dinero", "s4_no_tiempo_aprender_tbe",
                                  "s4_no_saber_tbe", "s4_entrenamiento_clinico_no_info_tbe",
                                  "s4_empleador_no_fondos_capacitacion_tbe"],
}
top5_strat = []
print("\nAPPROACH 4 — Stratified by conceptual domain:")
for domain, vars_in_domain in domains.items():
    valid = [v for v in vars_in_domain if v in std_across_clusters.index]
    best = std_across_clusters[valid].idxmax()
    top5_strat.append(best)
    print(f"  {domain:<25} -> {translation_dict.get(best,best):<50} std = {std_across_clusters[best]:.3f}")
top_vars_4 = {v: translation_dict.get(v, v) for v in top5_strat}
plot_radar(top_vars_4)


# APPROACH 5 — Between/within cluster variance ratio
_cds = features.copy()
_cds['Cluster'] = cluster_labels
sil_scores = {}
for var in features.columns:
    gm = _cds.groupby('Cluster')[var].mean()
    om = _cds[var].mean()
    ws = _cds.groupby('Cluster')[var].std().mean()
    bv = np.sum([len(_cds[_cds['Cluster'] == c]) * (gm[c] - om) ** 2
                 for c in _cds['Cluster'].unique()]) / len(_cds)
    if ws > 0:
        sil_scores[var] = np.sqrt(bv) / ws
sil_series = pd.Series(sil_scores).sort_values(ascending=False)
top_vars_5 = {v: translation_dict.get(v, v) for v in sil_series.head(5).index}
print("\nAPPROACH 5 — Top 5 by between/within cluster variance ratio:")
for v, s in sil_series.head(5).items():
    print(f"  {translation_dict.get(v,v):<55} ratio = {s:.3f}")
plot_radar(top_vars_5)


# SUMMARY
print("\n" + "="*70)
print("SUMMARY — Variables selected by each approach")
print("="*70)
for name, tv in [("Approach 1 (Variance)", top_vars_1), ("Approach 2 (PCA loading)", top_vars_2),
                 ("Approach 3 (ANOVA F)", top_vars_3), ("Approach 4 (Stratified)", top_vars_4),
                 ("Approach 5 (Between/Within)", top_vars_5)]:
    print(f"\n{name}:")
    for label in tv.values():
        print(f"  - {label}")
# Out:
# APPROACH 1 — Highest variance (std of cluster means):
#   Interest in Learning EBTs                               std = 2.368
#   Treatments with Empirical Basis                         std = 2.312
#   EBTs Attract Clients                                    std = 2.234
#   Scientific Findings in Daily Practice                   std = 2.210
#   Keeping Up with Scientific Research                     std = 2.204
# APPROACH 2 — Highest loading per PC (PC1-PC5):
#   PC1: Interest in Learning EBTs                               loading = -0.297
#   PC2: Clinical Training                                       loading = -0.347
#   PC3: No Time to Learn EBTs                                   loading = 0.344
#   PC4: Complexity of Clients vs. RCT Samples                   loading = -0.338
#   PC5: Diagnoses in RCTs Too Simple                            loading = -0.339
# APPROACH 3 — Top 5 by ANOVA F-statistic across clusters:
#   Interest in Learning EBTs                               F = 104.23
#   Scientific Findings in Daily Practice                   F = 95.19
#   Treatments with Empirical Basis                         F = 91.15
#   EBTs Attract Clients                                    F = 70.58
#   Keeping Up with Scientific Research                     F = 55.01
# APPROACH 4 — Stratified by conceptual domain:
#   EBT attitudes             -> Interest in Learning EBTs                          std = 2.368
#   Anti-EBT attitudes        -> Clinical Experience > Scientific Evidence          std = 1.353
#   Practice sources          -> Empirical Research (RCTs)                          std = 1.379
#   Influences on orientation -> Personal Therapy                                   std = 1.588
#   EBT barriers              -> EBT Training Too Expensive                         std = 1.592
# APPROACH 5 — Top 5 by between/within cluster variance ratio:
#   Interest in Learning EBTs                               ratio = 1.106
#   Treatments with Empirical Basis                         ratio = 1.079
#   Scientific Findings in Daily Practice                   ratio = 1.058
#   EBTs Attract Clients                                    ratio = 0.942
#   Supervisors Require EBTs                                ratio = 0.836
# ======================================================================
# SUMMARY — Variables selected by each approach
# ======================================================================
#
# Approach 1 (Variance):
#   - Interest in Learning EBTs
#   - Treatments with Empirical Basis
#   - EBTs Attract Clients
#   - Scientific Findings in Daily Practice
#   - Keeping Up with Scientific Research
#
# Approach 2 (PCA loading):
#   - Interest in Learning EBTs
#   - Clinical Training
#   - No Time to Learn EBTs
#   - Complexity of Clients vs. RCT Samples
#   - Diagnoses in RCTs Too Simple
#
# Approach 3 (ANOVA F):
#   - Interest in Learning EBTs
#   - Scientific Findings in Daily Practice
#   - Treatments with Empirical Basis
#   - EBTs Attract Clients
#   - Keeping Up with Scientific Research
#
# Approach 4 (Stratified):
#   - Interest in Learning EBTs
#   - Clinical Experience > Scientific Evidence
#   - Empirical Research (RCTs)
#   - Personal Therapy
#   - EBT Training Too Expensive
#
# Approach 5 (Between/Within):
#   - Interest in Learning EBTs
#   - Treatments with Empirical Basis
#   - Scientific Findings in Daily Practice
#   - EBTs Attract Clients
#   - Supervisors Require EBTs

# %% [markdown]
# ## 4. ANOVA and Logistic Regression

# %% [markdown]
# ### 4.1 ANOVA to compare gender, age, and weekly hours across the clusters

# %%
# Filter dataset to include only Masculino and Femenino in s1_genero
filtered_data = all_data_clean[all_data_clean['s1_genero'].isin(["Masculino", "Femenino"])].copy()

# Encode gender as binary (Masculino=0, Femenino=1)
filtered_data['s1_genero_encoded'] = filtered_data['s1_genero'].map({"Masculino": 0, "Femenino": 1})

# Descriptive statistics for variables across all clusters
age_stats = filtered_data.groupby('Cluster')['s1_edad'].describe()
hours_stats = filtered_data.groupby('Cluster')['s1_horas_semana_pacientes_atendidos'].describe()
gender_stats = filtered_data.groupby('Cluster')['s1_genero_encoded'].describe()

print("\n--- Descriptive Statistics for Age ---")
print(age_stats)
print("\n--- Descriptive Statistics for Patient Hours ---")
print(hours_stats)
print("\n--- Descriptive Statistics for Gender ---")
print(gender_stats)

sns.set_theme(style="whitegrid")

# Create a figure with 3 subplots (1 row, 3 columns)
fig, axes = plt.subplots(1, 3, figsize=(20, 6))  # 1 row, 3 columns

# ---- 1. Age Distribution ----
sns.boxplot(data=filtered_data, x='Cluster', y='s1_edad',
            hue='Cluster',  # Fix: Explicitly assign hue
            palette=["#9AC529", "#42B9B2", "#DE237B", "#F38A31"],
            width=0.6, linewidth=1.5, fliersize=3, 
            boxprops=dict(alpha=0.75), ax=axes[0], legend=False)  # Disable legend
sns.stripplot(data=filtered_data, x='Cluster', y='s1_edad',
              color="black", alpha=0.5, jitter=True, size=4, ax=axes[0])
#axes[0].set_title('Age Distribution Across Clusters', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Cluster', fontsize=12, fontweight='bold')
axes[0].set_ylabel('Age', fontsize=12, fontweight='bold')
axes[0].tick_params(axis='both', labelsize=11)
axes[0].grid(True, linestyle='--', alpha=0.5)

# ---- 2. Gender Distribution (Stacked Bar Plot) ----
gender_counts = filtered_data.groupby(['Cluster', 's1_genero_encoded']).size().unstack()
gender_proportions = gender_counts.div(gender_counts.sum(axis=1), axis=0)
gender_proportions.plot(kind='bar', stacked=True, 
                        color=["#42B9B2", "#DE237B"], edgecolor="black", 
                        ax=axes[1], width=0.7)
#axes[1].set_title('Gender Distribution Across Clusters', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Cluster', fontsize=12, fontweight='bold')
axes[1].set_ylabel('Proportion', fontsize=12, fontweight='bold')
axes[1].tick_params(axis='both', labelsize=11)
axes[1].legend(["Male", "Female"], title="Gender", fontsize=10, title_fontsize=12, frameon=True)
axes[1].grid(axis='y', linestyle='--', alpha=0.5)

# ---- 3. Patient Hours Distribution ----
sns.boxplot(data=filtered_data, x='Cluster', y='s1_horas_semana_pacientes_atendidos',
            hue='Cluster',  # Fix: Explicitly assign hue
            palette=["#9AC529", "#42B9B2", "#DE237B", "#F38A31"],
            width=0.6, linewidth=1.5, fliersize=3, 
            boxprops=dict(alpha=0.75), ax=axes[2], legend=False)  # Disable legend
sns.stripplot(data=filtered_data, x='Cluster', y='s1_horas_semana_pacientes_atendidos',
              color="black", alpha=0.5, jitter=True, size=4, ax=axes[2])
#axes[2].set_title('Patient Hours Distribution Across Clusters', fontsize=14, fontweight='bold')
axes[2].set_xlabel('Cluster', fontsize=12, fontweight='bold')
axes[2].set_ylabel('Patient Hours', fontsize=12, fontweight='bold')
axes[2].tick_params(axis='both', labelsize=11)
axes[2].grid(True, linestyle='--', alpha=0.5)

# Adjust layout
plt.tight_layout()
plt.show()
fig.savefig("multinomial_logistic_regression.png", dpi=300, bbox_inches='tight')

# ANOVA test for differences across clusters
anova_age = f_oneway(
    filtered_data[filtered_data['Cluster'] == 0]['s1_edad'],
    filtered_data[filtered_data['Cluster'] == 1]['s1_edad'],
    filtered_data[filtered_data['Cluster'] == 2]['s1_edad'],
    filtered_data[filtered_data['Cluster'] == 3]['s1_edad']
)
print(f"ANOVA for Age: F={anova_age.statistic:.2f}, p={anova_age.pvalue:.4f}")

anova_hours = f_oneway(
    filtered_data[filtered_data['Cluster'] == 0]['s1_horas_semana_pacientes_atendidos'],
    filtered_data[filtered_data['Cluster'] == 1]['s1_horas_semana_pacientes_atendidos'],
    filtered_data[filtered_data['Cluster'] == 2]['s1_horas_semana_pacientes_atendidos'],
    filtered_data[filtered_data['Cluster'] == 3]['s1_horas_semana_pacientes_atendidos']
)
print(f"ANOVA for Patient Hours: F={anova_hours.statistic:.2f}, p={anova_hours.pvalue:.4f}")

anova_gender = f_oneway(
    filtered_data[filtered_data['Cluster'] == 0]['s1_genero_encoded'],
    filtered_data[filtered_data['Cluster'] == 1]['s1_genero_encoded'],
    filtered_data[filtered_data['Cluster'] == 2]['s1_genero_encoded'],
    filtered_data[filtered_data['Cluster'] == 3]['s1_genero_encoded']
)
print(f"ANOVA for Gender: F={anova_gender.statistic:.2f}, p={anova_gender.pvalue:.4f}")
# Out:
# --- Descriptive Statistics for Age ---
#          count       mean        std   min    25%   50%    75%   max
# Cluster
# 0         52.0  29.615385   4.173464  24.0  26.75  28.5  32.25  41.0
# 1         75.0  36.426667   9.402664  23.0  29.00  35.0  41.00  61.0
# 2         85.0  32.705882   7.092624  21.0  27.00  31.0  37.00  55.0
# 3         46.0  40.652174  11.743968  25.0  31.50  38.0  47.00  77.0
#
# --- Descriptive Statistics for Patient Hours ---
#          count       mean        std  min    25%   50%   75%   max
# Cluster
# 0         52.0  18.942308  11.568065  2.0   9.75  16.0  27.0  48.0
# 1         75.0  26.053333  15.956777  0.0  14.00  24.0  37.0  75.0
# 2         85.0  23.764706  11.874991  2.0  15.00  21.0  30.0  65.0
# 3         46.0  30.130435  14.171346  3.0  20.00  30.0  40.0  75.0
#
# --- Descriptive Statistics for Gender ---
#          count      mean       std  min  25%  50%  75%  max
# Cluster
# 0         52.0  0.615385  0.491251  0.0  0.0  1.0  1.0  1.0
# 1         75.0  0.880000  0.327150  0.0  1.0  1.0  1.0  1.0
# 2         85.0  0.811765  0.393220  0.0  1.0  1.0  1.0  1.0
# 3         46.0  0.826087  0.383223  0.0  1.0  1.0  1.0  1.0
# ANOVA for Age: F=16.74, p=0.0000
# ANOVA for Patient Hours: F=5.98, p=0.0006
# ANOVA for Gender: F=4.86, p=0.0026

# %% [markdown]
# ### 4.2 Logistic Regression

# %%
# Filter dataset to include only Masculino and Femenino in s1_genero
filtered_data = all_data_clean[all_data_clean['s1_genero'].isin(["Masculino", "Femenino"])].copy()

# Encode gender as binary (Masculino=0, Femenino=1)
filtered_data['s1_genero_encoded'] = filtered_data['s1_genero'].map({"Masculino": 0, "Femenino": 1})

# Prepare data for multinomial logistic regression
predictors = ['s1_edad', 's1_horas_semana_pacientes_atendidos', 's1_genero_encoded']
X = filtered_data[predictors]
y = filtered_data['Cluster']

# Standardize predictors
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Add intercept term
X_scaled = sm.add_constant(X_scaled)

# Fit multinomial logistic regression model using statsmodels
log_reg = sm.MNLogit(y, X_scaled)
result = log_reg.fit()

# Print summary of the model
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 1.214613
#          Iterations 7
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:                Cluster   No. Observations:                  258
# Model:                        MNLogit   Df Residuals:                      246
# Method:                           MLE   Df Model:                            9
# Date:                Sat, 21 Mar 2026   Pseudo R-squ.:                  0.1037
# Time:                        10:45:38   Log-Likelihood:                -313.37
# converged:                       True   LL-Null:                       -349.64
# Covariance Type:            nonrobust   LLR p-value:                 4.808e-12
# ==============================================================================
#  Cluster=1       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.8262      0.251      3.289      0.001       0.334       1.319
# x1             1.2611      0.321      3.930      0.000       0.632       1.890
# x2             0.5440      0.221      2.458      0.014       0.110       0.978
# x3             0.6794      0.199      3.409      0.001       0.289       1.070
# ------------------------------------------------------------------------------
#  Cluster=2       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.9750      0.247      3.952      0.000       0.491       1.458
# x1             0.7770      0.317      2.448      0.014       0.155       1.399
# x2             0.3909      0.209      1.873      0.061      -0.018       0.800
# x3             0.4478      0.168      2.667      0.008       0.119       0.777
# ------------------------------------------------------------------------------
#  Cluster=3       coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1560      0.281      0.555      0.579      -0.395       0.707
# x1             1.6094      0.334      4.813      0.000       0.954       2.265
# x2             0.7710      0.246      3.131      0.002       0.288       1.254
# x3             0.5342      0.224      2.382      0.017       0.095       0.974
# ==============================================================================

# %% [markdown]
# ## 5. Visualizations

# %% [markdown]
# ### 5.1 Clusters in PCA Space

# %%
# Ensure cluster labels are in the dataset
all_data_clean = all_data_clean.copy()
all_data_clean['Cluster'] = cluster_labels

# Define colorblind-friendly palette and distinct markers
palette = sns.color_palette("colorblind", len(np.unique(cluster_labels)))
markers = ['o', 's', 'D', '^']  

# Define custom cluster labels
cluster_labels_map = {
    0: "Cluster 0 (CBT dominant)",
    1: "Cluster 1 (CBT mixed)",
    2: "Cluster 2 (Mixed Orientations)",
    3: "Cluster 3 (Psychoanalysis Dominant)"
}

# Create figure
plt.figure(figsize=(8, 6))

# Loop through clusters and plot with different markers
for i, cluster in enumerate(np.unique(cluster_labels)):
    plt.scatter(pca_reduced_data[cluster_labels == cluster, 0], 
                pca_reduced_data[cluster_labels == cluster, 1], 
                label=cluster_labels_map.get(cluster, f'Cluster {cluster}'),  # Use the mapping
                color=palette[i], 
                marker=markers[i % len(markers)],  # Assign markers cyclically
                alpha=0.75, edgecolor='black')

# Formatting improvements
plt.title('Clusters in PCA Space', fontsize=14, fontweight='bold')
plt.xlabel('Principal Component 1', fontsize=12, fontweight='bold')
plt.ylabel('Principal Component 2', fontsize=12, fontweight='bold')
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.grid(True, linestyle='--', alpha=0.5)  # Add subtle grid for better readability

# Improve legend
plt.legend(title="Cluster", fontsize=10, title_fontsize=12, frameon=True, loc='best')

plt.show()

# %% [markdown]
# ### 5.2 Heatmap For Clusters

# %%
# Define translation dictionary for theoretical orientations
orientation_translation = {
    'Terapias Cognitivas/Comportamentales': 'Cognitive-Behavioral Therapies',
    'Psicoanálisis': 'Psychoanalysis',
    'Ecléctico (más de una de estas opciones)': 'Eclectic (mixed theoretical orientations)',
    'Sistémica': 'Systemic'
}

# Apply translation to the orientation column
all_data_clean = all_data_clean.copy()
all_data_clean['s1_orientacion_teo'] = all_data_clean['s1_orientacion_teo'].replace(orientation_translation)

# Generate Cluster Distribution Heatmap
cluster_distribution = pd.crosstab(all_data_clean['Cluster'], all_data_clean['s1_orientacion_teo'])

# Set figure size
plt.figure(figsize=(10, 6))

# Create heatmap with colorblind-friendly "viridis" colormap
sns.heatmap(cluster_distribution, 
            annot=True, fmt='d', cmap='viridis', linewidths=0.5, 
            linecolor='white', cbar_kws={'label': 'Number of Practitioners'}, 
            annot_kws={"fontsize": 12, "fontweight": "bold"})

# Formatting
plt.title('Cluster Distribution Across Theoretical Orientations', fontsize=16, fontweight='bold', fontname='Times New Roman')
plt.xlabel('Theoretical Orientation', fontsize=14, fontweight='bold', fontname='Times New Roman')
plt.ylabel('Cluster', fontsize=14, fontweight='bold', fontname='Times New Roman')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right', fontsize=12, fontname='Times New Roman')
plt.yticks(fontsize=12, fontname='Times New Roman')

# Show plot
plt.show()
