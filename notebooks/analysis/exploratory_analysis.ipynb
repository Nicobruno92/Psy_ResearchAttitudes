# %% [markdown]
# # Data Analysis

# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Load Data

# %%
df = pd.read_csv('../../data/featured_data.csv')
df.head()
# Out:
#    s1_edad  s1_genero  s1_experiencia_clinica                s1_educacion  \
# 0     41.0   Femenino                     1.2       Licenciatura de Grado
# 1     26.0   Femenino                     0.2       Licenciatura de Grado
# 2     27.0   Femenino                     1.0  Carrera de Especialización
# 3     30.0  Masculino                     1.3  Carrera de Especialización
# 4     26.0  Masculino                     2.0       Licenciatura de Grado
#
#   s1_titulo_terciario           s1_titulo s1_no_titulo_universitario  \
# 0                 NaN  Lic. en Psicología                        NaN
# 1                 NaN  Lic. en Psicología                        NaN
# 2                 NaN  Lic. en Psicología                        NaN
# 3                 NaN  Lic. en Psicología                        NaN
# 4                 NaN  Lic. en Psicología                        NaN
#
#    s1_horas_semana_pacientes_atendidos                    s1_contexto_trabajo  \
# ...

# %% [markdown]
# ## 2. EDA

# %%
df.shape
# Out:
# (284, 56)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284 entries, 0 to 283
# Data columns (total 56 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   s1_edad                                                    283 non-null    float64
#  1   s1_genero                                                  283 non-null    object
#  2   s1_experiencia_clinica                                     283 non-null    float64
#  3   s1_educacion                                               283 non-null    object
#  4   s1_titulo_terciario                                        53 non-null     object
#  5   s1_titulo                                                  283 non-null    object
#  6   s1_no_titulo_universitario                                 2 non-null      object
# ...

# %%
df.describe()
# Out:
#           s1_edad  s1_experiencia_clinica  \
# count  283.000000              283.000000
# mean    35.137809                6.978516
# std      9.516620                8.867513
# min     21.000000                0.000000
# 25%     28.000000                1.600000
# 50%     33.000000                3.100000
# 75%     40.000000                9.000000
# max     77.000000               55.000000
#
#        s1_horas_semana_pacientes_atendidos  s1_marco_teo_terapia_basada_arte  \
# count                           283.000000                               0.0
# mean                             24.876325                               NaN
# std                              13.638529                               NaN
# min                               0.000000                               NaN
# 25%                              14.500000                               NaN
# 50%                              24.000000                               NaN
# ...

# %% [markdown]
# ## 3. Sections

# %% [markdown]
# ### Section 1

# %% [markdown]
# ### Section 2

# %%
s2 = df.filter(regex='s2')

tcc = df[df['s1_orientacion_teo']=='Terapias Cognitivas/Comportamentales']
psa = df[df['s1_orientacion_teo']=='Psicoanálisis']
eclectico = df[df['s1_orientacion_teo']=='Ecléctico (más de una de estas opciones)']
sistemico = df[df['s1_orientacion_teo'] =='Sistémica']


s2_tcc = tcc[['s2_evidencia_cientifica','s2_experiencia_personal','s2_entrenamiento_clinica',
                      's2_tratamiento_preferencia_consultantes','s2_intuicion','s2_terapia_personal']].mean()

s2_psa =  psa[['s2_evidencia_cientifica','s2_experiencia_personal','s2_entrenamiento_clinica',
                      's2_tratamiento_preferencia_consultantes','s2_intuicion','s2_terapia_personal']].mean()

s2_eclectico = eclectico[['s2_evidencia_cientifica','s2_experiencia_personal','s2_entrenamiento_clinica',
                      's2_tratamiento_preferencia_consultantes','s2_intuicion','s2_terapia_personal']].mean()

s2_sistemico = sistemico[['s2_evidencia_cientifica','s2_experiencia_personal','s2_entrenamiento_clinica',
                      's2_tratamiento_preferencia_consultantes','s2_intuicion','s2_terapia_personal']].mean()

df2 = {
    'PSA': s2_psa.round(2),
    'TCC': s2_tcc.round(2),
    'ECLECTICO': s2_eclectico.round(2),
    'SISTEMICA': s2_sistemico.round(2)
}

df2 = pd.DataFrame(df2)
df2
# Out:
#                                           PSA   TCC  ECLECTICO  SISTEMICA
# s2_evidencia_cientifica                  4.15  6.58       5.06       5.50
# s2_experiencia_personal                  5.91  5.28       5.77       5.21
# s2_entrenamiento_clinica                 5.96  5.24       5.22       5.71
# s2_tratamiento_preferencia_consultantes  4.00  3.39       3.76       3.79
# s2_intuicion                             3.65  3.08       3.89       3.36
# s2_terapia_personal                      6.33  4.27       4.48       4.29

# %%
ax = df2.plot(kind='barh', figsize=(10,10), width=0.8)

ax.set_xlabel('Puntaje')
ax.set_ylabel('Variables')
ax.set_title('Medias segun marco teo')
plt.show()

# %% [markdown]
# ### Section 3

# %%
s3 = df.filter(regex='s3')

s3_psa = psa[['s3_tratamiento_personal_consultantes','s3_investigacion_empirica_ensayos_controlados',\
                         's3_supervision','s3_estudios_de_caso','s3_discusion_pares','s3_libros','s3_observaciones_casos_clinicos',\
                         's3_medidas_resultado','s3_guias_manuales_clinicos']].mean() 

s3_tcc = tcc[['s3_tratamiento_personal_consultantes','s3_investigacion_empirica_ensayos_controlados',\
                         's3_supervision','s3_estudios_de_caso','s3_discusion_pares','s3_libros','s3_observaciones_casos_clinicos',\
                         's3_medidas_resultado','s3_guias_manuales_clinicos']].mean()

s3_eclectico = eclectico[['s3_tratamiento_personal_consultantes','s3_investigacion_empirica_ensayos_controlados',\
                         's3_supervision','s3_estudios_de_caso','s3_discusion_pares','s3_libros','s3_observaciones_casos_clinicos',\
                         's3_medidas_resultado','s3_guias_manuales_clinicos']].mean()

s3_sistemico = sistemico[['s3_tratamiento_personal_consultantes','s3_investigacion_empirica_ensayos_controlados',\
                         's3_supervision','s3_estudios_de_caso','s3_discusion_pares','s3_libros','s3_observaciones_casos_clinicos',\
                         's3_medidas_resultado','s3_guias_manuales_clinicos']].mean()

# dataframe for 3rd section
df3 = {
    'PSA': s3_psa.round(2),
    'TCC': s3_tcc.round(2),
    'ECLECTICO': s3_eclectico.round(2),
    'SISTEMICA': s3_sistemico.round(2)
}

df3 = pd.DataFrame(df3)
df3
# Out:
#                                                 PSA   TCC  ECLECTICO  \
# s3_tratamiento_personal_consultantes           5.91  5.36       5.34
# s3_investigacion_empirica_ensayos_controlados  2.51  4.35       3.19
# s3_supervision                                 6.18  5.25       5.09
# s3_estudios_de_caso                            4.25  4.02       3.66
# s3_discusion_pares                             6.18  5.68       5.66
# s3_libros                                      6.39  6.15       5.75
# s3_observaciones_casos_clinicos                5.90  3.99       4.56
# s3_medidas_resultado                           2.15  4.19       3.28
# s3_guias_manuales_clinicos                     3.24  5.90       5.03
#
#                                                SISTEMICA
# s3_tratamiento_personal_consultantes                5.86
# s3_investigacion_empirica_ensayos_controlados       3.93
# s3_supervision                                      5.57
# ...

# %%
ax = df3.plot(kind='barh', figsize=(10,10), width=0.8)

ax.set_xlabel('Puntaje')
ax.set_ylabel('Variables')
ax.set_title('Fuentes Utilizadas')
plt.show()

# %% [markdown]
# ### Section 4

# %%
s4 = df.filter(regex='s4')
s4.head()
# Out:
#    s4_apertura_terapias_desarrolladas_por_investigadores  \
# 0                                                4.0
# 1                                                4.0
# 2                                                7.0
# 3                                                6.0
# 4                                                7.0
#
#    s4_actualizacion_info_cientifica  s4_formacion_enfasis_investigacion  \
# 0                               0.0                                 5.0
# 1                               7.0                                 7.0
# 2                               0.0                                 7.0
# 3                               0.0                                 7.0
# 4                               4.0                                 4.0
#
#    s4_supervisores_terapia_evidencia_requerimiento  \
# 0                                              3.0
# 1                                              0.0
# ...

# %%
s4_psa = psa[['s4_apertura_terapias_desarrolladas_por_investigadores',
                        's4_nueva_terapia_intento','s4_terapia_manualizada',
                         's4_diagnosticos_utilizados_son_simples','s4_tratamientos_preferencia_no_probados_ensayo_controlado',
                         's4_enfoque_tratamiento_individual','s4_alianza_terapeutica_mas_importante',
                         's4_terapias_igualmente_efectivas','s4_exp_clinica_+imp_que_evidencia_cientifica',
                          's4_actualizacion_info_cientifica',
                         's4_formacion_enfasis_investigacion','s4_supervisores_terapia_evidencia_requerimiento',
                         's4_atraer_consultantes_con_tbe',
                         's4_hallazgos_cientificos_practica_diaria','s4_interes_aprender_tbe',
                         's4_tratamientos_utilizados_base_empirica','s4_complejidad_consultantes_ensayos_clinicos',
                         's4_consultantes_prefieren_otros_tratamientos',
                         's4_no_tiempo_aprender_tbe','s4_capacitacion_tbe_demasiado_dinero',
                         's4_no_saber_tbe','s4_entrenamiento_clinico_no_info_tbe',
                         's4_empleador_no_fondos_capacitacion_tbe','s4_exp_clinica_+imp_que_evidencia_cientifica']].mean()

s4_tcc = tcc[['s4_apertura_terapias_desarrolladas_por_investigadores',
                        's4_nueva_terapia_intento','s4_terapia_manualizada',
                         's4_diagnosticos_utilizados_son_simples','s4_tratamientos_preferencia_no_probados_ensayo_controlado',
                         's4_enfoque_tratamiento_individual','s4_alianza_terapeutica_mas_importante',
                         's4_terapias_igualmente_efectivas','s4_exp_clinica_+imp_que_evidencia_cientifica',
                          's4_actualizacion_info_cientifica',
                         's4_formacion_enfasis_investigacion','s4_supervisores_terapia_evidencia_requerimiento',
                         's4_atraer_consultantes_con_tbe',
                         's4_hallazgos_cientificos_practica_diaria','s4_interes_aprender_tbe',
                         's4_tratamientos_utilizados_base_empirica','s4_complejidad_consultantes_ensayos_clinicos',
                         's4_consultantes_prefieren_otros_tratamientos',
                         's4_no_tiempo_aprender_tbe','s4_capacitacion_tbe_demasiado_dinero',
                         's4_no_saber_tbe','s4_entrenamiento_clinico_no_info_tbe',
                         's4_empleador_no_fondos_capacitacion_tbe','s4_exp_clinica_+imp_que_evidencia_cientifica']].mean()

s4_eclectico = eclectico[['s4_apertura_terapias_desarrolladas_por_investigadores',
                        's4_nueva_terapia_intento','s4_terapia_manualizada',
                         's4_diagnosticos_utilizados_son_simples','s4_tratamientos_preferencia_no_probados_ensayo_controlado',
                         's4_enfoque_tratamiento_individual','s4_alianza_terapeutica_mas_importante',
                         's4_terapias_igualmente_efectivas','s4_exp_clinica_+imp_que_evidencia_cientifica',
                          's4_actualizacion_info_cientifica',
                         's4_formacion_enfasis_investigacion','s4_supervisores_terapia_evidencia_requerimiento',
                         's4_atraer_consultantes_con_tbe',
                         's4_hallazgos_cientificos_practica_diaria','s4_interes_aprender_tbe',
                         's4_tratamientos_utilizados_base_empirica','s4_complejidad_consultantes_ensayos_clinicos',
                         's4_consultantes_prefieren_otros_tratamientos',
                         's4_no_tiempo_aprender_tbe','s4_capacitacion_tbe_demasiado_dinero',
                         's4_no_saber_tbe','s4_entrenamiento_clinico_no_info_tbe',
                         's4_empleador_no_fondos_capacitacion_tbe','s4_exp_clinica_+imp_que_evidencia_cientifica']].mean()

s4_sistemico = sistemico[['s4_apertura_terapias_desarrolladas_por_investigadores',
                        's4_nueva_terapia_intento','s4_terapia_manualizada',
                         's4_diagnosticos_utilizados_son_simples','s4_tratamientos_preferencia_no_probados_ensayo_controlado',
                         's4_enfoque_tratamiento_individual','s4_alianza_terapeutica_mas_importante',
                         's4_terapias_igualmente_efectivas','s4_exp_clinica_+imp_que_evidencia_cientifica',
                          's4_actualizacion_info_cientifica',
                         's4_formacion_enfasis_investigacion','s4_supervisores_terapia_evidencia_requerimiento',
                         's4_atraer_consultantes_con_tbe',
                         's4_hallazgos_cientificos_practica_diaria','s4_interes_aprender_tbe',
                         's4_tratamientos_utilizados_base_empirica','s4_complejidad_consultantes_ensayos_clinicos',
                         's4_consultantes_prefieren_otros_tratamientos',
                         's4_no_tiempo_aprender_tbe','s4_capacitacion_tbe_demasiado_dinero',
                         's4_no_saber_tbe','s4_entrenamiento_clinico_no_info_tbe',
                         's4_empleador_no_fondos_capacitacion_tbe','s4_exp_clinica_+imp_que_evidencia_cientifica']].mean()

df4 = {
    'PSA': s4_psa.round(2),
    'TCC': s4_tcc.round(2),
    'ECLECTICO': s4_eclectico.round(2),
    'SISTEMICA': s4_sistemico.round(2)
}

df4 = pd.DataFrame(df4)
df4
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 s4_psa = psa[['s4_apertura_terapias_desarrolladas_por_investigadores',
#       2                         's4_nueva_terapia_intento','s4_terapia_manualizada',
#       3                          's4_diagnosticos_utilizados_son_simples','s4_tratamientos_preferencia_no_probados_ensayo_controlado',
#       4                          's4_enfoque_tratamiento_individual','s4_alianza_terapeutica_mas_importante',
#       5                          's4_terapias_igualmente_efectivas','s4_exp_clinica_+imp_que_evidencia_cientifica',
#       6                           's4_actualizacion_info_cientifica',
#       7                          's4_formacion_enfasis_investigacion','s4_supervisores_terapia_evidencia_requerimiento',
#       8                          's4_atraer_consultantes_con_tbe',
# ...

# %%
ax = df4.plot(kind='barh', figsize=(15,15), width=0.8)

ax.set_xlabel('Puntaje')
ax.set_ylabel('Variables')
ax.set_title('Frases a Valorar')
plt.show()

# %% [markdown]
# ### Consentimiento Informado

# %%
ci_psa = psa['consentimiento_informado'].mean()
ci_tcc = tcc['consentimiento_informado'].mean()
ci_eclectico = eclectico['consentimiento_informado'].mean()
ci_sistemico = sistemico['consentimiento_informado'].mean()

print('CI PSA:',ci_psa)
print('CI TCC:',ci_tcc)
print('CI ELECTICO:',ci_eclectico)
print('CI SISTEMICA:',ci_sistemico)
# Out:
# CI PSA: 5.947368421052632
# CI TCC: 6.065573770491803
# CI ELECTICO: 5.310344827586207
# CI SISTEMICA: 6.285714285714286
