# %% [markdown]
# # Data Featuring

# %%
import pandas as pd 
import numpy as np
from data_cleaning import data_featuring

# %%
df = pd.read_csv("../../data/preprocessed.csv")
df.head()
# Out:
#             Timestamp participacion  s1_edad  s1_genero
# 0  2/24/2023 17:49:30            Sí     41.0   Femenino  \
# 1  2/24/2023 17:50:27            Sí     26.0   Femenino
# 2  2/24/2023 17:52:36            Sí     27.0   Femenino
# 3  2/24/2023 17:58:18            Sí     30.0  Masculino
# 4  2/24/2023 18:05:06            Sí     26.0  Masculino
#
#    s1_experiencia_clinica                s1_educacion s1_titulo_terciario
# 0                     1.2       Licenciatura de Grado                 NaN  \
# 1                     0.2       Licenciatura de Grado                 NaN
# 2                     1.0  Carrera de Especialización                 NaN
# 3                     1.3  Carrera de Especialización                 NaN
# 4                     2.0       Licenciatura de Grado                 NaN
#
#             s1_titulo s1_no_titulo_universitario
# 0  Lic. en Psicología                        NaN  \
# 1  Lic. en Psicología                        NaN
# ...

# %%
df = data_featuring(df)
df.head()
# Out:
#    s1_edad  s1_genero  s1_experiencia_clinica                s1_educacion
# 0     41.0   Femenino                     1.2       Licenciatura de Grado  \
# 1     26.0   Femenino                     0.2       Licenciatura de Grado
# 2     27.0   Femenino                     1.0  Carrera de Especialización
# 3     30.0  Masculino                     1.3  Carrera de Especialización
# 4     26.0  Masculino                     2.0       Licenciatura de Grado
#
#   s1_titulo_terciario           s1_titulo s1_no_titulo_universitario
# 0                 NaN  Lic. en Psicología                        NaN  \
# 1                 NaN  Lic. en Psicología                        NaN
# 2                 NaN  Lic. en Psicología                        NaN
# 3                 NaN  Lic. en Psicología                        NaN
# 4                 NaN  Lic. en Psicología                        NaN
#
#    s1_horas_semana_pacientes_atendidos                    s1_contexto_trabajo
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284 entries, 0 to 283
# Data columns (total 56 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   s1_edad                                                    283 non-null    float64
#  1   s1_genero                                                  283 non-null    object
#  2   s1_experiencia_clinica                                     283 non-null    float64
#  3   s1_educacion                                               283 non-null    object
#  4   s1_titulo_terciario                                        53 non-null     object
#  5   s1_titulo                                                  283 non-null    object
#  6   s1_no_titulo_universitario                                 2 non-null      object
# ...
